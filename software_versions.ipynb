# %% [markdown]
# # Software Versions

# %%
import sys
# Python Version
print(sys.version)
# Out:
# 3.10.17 | packaged by conda-forge | (main, Apr 10 2025, 22:23:34) [Clang 18.1.8 ]

# %% [markdown]
# ### Standard library modules

# %%
import ast
import os
import shutil
import time
import base64
import io
import glob
import subprocess
import colorsys

# %% [markdown]
# ### Third-party modules

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.3

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.2.4

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import requests
print(requests.__version__)
# Out:
# 2.32.3

# %%
import openai
print(openai.__version__)
# Out:
# 1.38.0

# %%
import PIL
print(PIL.__version__)
# Out:
# 11.1.0

# %%
import json
print(json.__version__)
# Out:
# 2.0.9

# %%
import csv
print(csv.__version__)
# Out:
# 1.0

# %%
import re
print(re.__version__)
# Out:
# 2.2.1

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.11.0

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import skimage
print(skimage.__version__)
# Out:
# 0.25.2

# %%
import shapely
print(shapely.__version__)
# Out:
# 2.1.0

# %%
import cartopy
print(cartopy.__version__)
# Out:
# 0.24.1

# %%
import geopandas
print(geopandas.__version__)
# Out:
# 1.0.1

# %%
import pyproj
print(pyproj.__version__)
# Out:
# 3.7.1

# %%
import seaborn
print(seaborn.__version__)
# Out:
# 0.13.2

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.15.2

# %%
import pingouin
print(pingouin.__version__)
# Out:
# 0.5.5

# %%
import rasterio
print(rasterio.__version__)
# Out:
# 1.4.3

# %%
import contextily
print(contextily.__version__)
# Out:
# 1.6.2

# %%
import shapely
print(shapely.__version__)
# Out:
# 2.1.0

# %%
import statsmodels
print(statsmodels.__version__)
# Out:
# 0.14.4

# %%
# python-colormath doesn't have a __version__ attribute
import importlib.metadata
print(importlib.metadata.version("colormath"))
# Out:
# 3.0.0
