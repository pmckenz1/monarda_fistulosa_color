# %% [markdown]
# # Figure 1

# %% [markdown]
# ### Getting map figure

# %% [markdown]
# (Just imported other maps and cleared off the points)

# %% [markdown]
# ### Getting image locations

# %%
import pandas as pd
import numpy as np

# %%
color_df = pd.read_csv('../datasets/1-clusters/cluster1.csv')

# %%
# 284 (1st image) NO LONGER

print(color_df[color_df.image_idx.eq(284)][['latitude','longitude']].reset_index())

# 19 (2nd image)

print(color_df[color_df.image_idx.eq(19)][['latitude','longitude']].reset_index())

# 227 (3rd image) 

print(color_df[color_df.image_idx.eq(227)][['latitude','longitude']].reset_index())

# 232 (4th image)

print(color_df[color_df.image_idx.eq(232)][['latitude','longitude']].reset_index())
# Out:
#    index   latitude   longitude
# 0    117  35.945797 -106.670988
#    index   latitude  longitude
# 0      9  43.859333 -72.588667
#    index   latitude   longitude
# 0     89  35.684884 -105.356642
#    index   latitude  longitude
# 0     91  41.986913  -87.68858

# %%
# 198 (REPLACEMENT)
print(color_df[color_df.image_idx.eq(198)][['latitude','longitude']].reset_index())
# Out:
#    index   latitude   longitude
# 0     70  56.285658 -120.750086
